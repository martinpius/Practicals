# %% [markdown]
# <a href="https://colab.research.google.com/github/martinpius/Practicals/blob/main/CS_329_Python_programming_warm_up_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Programming Warm-Up Exercise
# ## CS 329: Introduction to Big Data Analytics
#
# **Duration:** One week: Submit in our next class.
# **Submission file name:** `Your Name  and Reg #: `
#
# ### Purpose of this exercise
# This notebook is designed to help you practise basic Python programming skills that are useful in introductory big data analytics. You will create a small dataset, convert it into a Pandas DataFrame, inspect the data, calculate summary statistics, filter records, group data, sort observations, and produce basic visualizations.
#
# Although the dataset is small, the skills you practise here are the same skills used when working with large datasets.

# %% [markdown]
# ## Learning Outcomes
#
# By the end of this exercise, you should be able to:
#
# 1. Create a simple dataset using Python lists and dictionaries.
# 2. Convert raw data into a Pandas DataFrame.
# 3. Inspect the structure and quality of a dataset.
# 4. Compute descriptive statistics.
# 5. Create new variables from existing variables.
# 6. Filter, group, and sort data.
# 7. Produce basic visualizations using Matplotlib.
# 8. Explain how Python supports data analytics.

# %% [markdown]
# ## Instructions
#
# Read each task carefully and write your code in the cells provided. Some code has already been provided to help you get started. You are encouraged to add additional code cells where necessary.
#
# Before submission, make sure that:
#
# - All code cells run successfully.
# - Your outputs are visible.
# - Your charts are properly labelled.
# - Your written answers are clear and complete.
# - Pres shift + Enter to run or click the play button

# %% [markdown]
# ## Task 0: Import Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# This makes plots appear inside the notebook
# %matplotlib inline

# %% [markdown]
# ## Task 1: Create a Student Dataset
#
# Create a Python list of dictionaries containing information for at least **15 students**.
#
# Each student should have the following variables:
#
# - `student_id`
# - `name`
# - `gender`
# - `age`
# - `program`
# - `year_of_study`
# - `python_score`
# - `statistics_score`
# - `database_score`
#
# A starter dataset is provided below. You may use it as it is, or modify it by adding your own names and values.

# %%
students = [
    {"student_id": "S001", "name": "Asha", "gender": "Female", "age": 21, "program": "BSc Statistics", "year_of_study": 2, "python_score": 78, "statistics_score": 82, "database_score": 74},
    {"student_id": "S002", "name": "Baraka", "gender": "Male", "age": 22, "program": "BSc Computer Science", "year_of_study": 2, "python_score": 65, "statistics_score": 70, "database_score": 68},
    {"student_id": "S003", "name": "Neema", "gender": "Female", "age": 20, "program": "BSc Data Science", "year_of_study": 1, "python_score": 88, "statistics_score": 84, "database_score": 80},
    {"student_id": "S004", "name": "Juma", "gender": "Male", "age": 23, "program": "BSc Statistics", "year_of_study": 3, "python_score": 55, "statistics_score": 60, "database_score": 58},
    {"student_id": "S005", "name": "Rehema", "gender": "Female", "age": 21, "program": "BSc Computer Science", "year_of_study": 2, "python_score": 92, "statistics_score": 89, "database_score": 94},
    {"student_id": "S006", "name": "Moses", "gender": "Male", "age": 24, "program": "BSc Data Science", "year_of_study": 3, "python_score": 73, "statistics_score": 75, "database_score": 70},
    {"student_id": "S007", "name": "Fatuma", "gender": "Female", "age": 22, "program": "BSc Statistics", "year_of_study": 2, "python_score": 81, "statistics_score": 79, "database_score": 77},
    {"student_id": "S008", "name": "Peter", "gender": "Male", "age": 20, "program": "BSc Computer Science", "year_of_study": 1, "python_score": 49, "statistics_score": 55, "database_score": 52},
    {"student_id": "S009", "name": "Grace", "gender": "Female", "age": 23, "program": "BSc Data Science", "year_of_study": 3, "python_score": 86, "statistics_score": 90, "database_score": 85},
    {"student_id": "S010", "name": "Hassan", "gender": "Male", "age": 21, "program": "BSc Statistics", "year_of_study": 1, "python_score": 67, "statistics_score": 72, "database_score": 69},
    {"student_id": "S011", "name": "Zawadi", "gender": "Female", "age": 22, "program": "BSc Computer Science", "year_of_study": 2, "python_score": 74, "statistics_score": 71, "database_score": 79},
    {"student_id": "S012", "name": "Kelvin", "gender": "Male", "age": 25, "program": "BSc Data Science", "year_of_study": 3, "python_score": 59, "statistics_score": 64, "database_score": 61},
    {"student_id": "S013", "name": "Upendo", "gender": "Female", "age": 20, "program": "BSc Statistics", "year_of_study": 1, "python_score": 83, "statistics_score": 87, "database_score": 81},
    {"student_id": "S014", "name": "Daniel", "gender": "Male", "age": 22, "program": "BSc Computer Science", "year_of_study": 2, "python_score": 76, "statistics_score": 69, "database_score": 73},
    {"student_id": "S015", "name": "Mariam", "gender": "Female", "age": 24, "program": "BSc Data Science", "year_of_study": 3, "python_score": 90, "statistics_score": 92, "database_score": 88}
]

# %% [markdown]
# ## Task 2: Convert the Dataset into a Pandas DataFrame

# %%
df = # your code
df.head()
# Out:
#   student_id    name  gender  age               program  year_of_study  \
# 0       S001    Asha  Female   21        BSc Statistics              2
# 1       S002  Baraka    Male   22  BSc Computer Science              2
# 2       S003   Neema  Female   20      BSc Data Science              1
# 3       S004    Juma    Male   23        BSc Statistics              3
# 4       S005  Rehema  Female   21  BSc Computer Science              2
#
#    python_score  statistics_score  database_score
# 0            78                82              74
# 1            65                70              68
# 2            88                84              80
# 3            55                60              58
# 4            92                89              94

# %% [markdown]
# ## Task 3: Basic Data Inspection
#
# Use Python commands to answer the following questions:
#
# 1. How many students are in the dataset?
# 2. How many columns are in the dataset?
# 3. What are the column names?
# 4. What are the data types of each column?
# 5. Are there any missing values?

# %%
# 1. Number of students (your code)

# %%
# 2. Number of rows and columns (your code)

# %%
# 3. Column names (your code)

# %%
# 4. Data types (your code)

# %%
# 5. Missing values (your code)

# %% [markdown]
# ## Task 4: Descriptive Statistics
#
# Calculate the following:
#
# 1. Average Python score.
# 2. Average Statistics score.
# 3. Average Database score.
# 4. Minimum and maximum Python score.
# 5. The oldest and youngest student.

# %%
# Average Python score (your code)

# %%
# Average Statistics score (your code)

# %%
# Average Database score (your code)

# %%
# Minimum and maximum Python score (your code)

# %%
# Oldest and youngest student (your code)

# %% [markdown]
# ## Task 5: Create New Columns
#
# Create a new column called `average_score`. This column should contain the average of Python, Statistics, and Database scores.

# %%
df["average_score"] = # Your code

df.head()
# Out:
#   student_id    name  gender  age               program  year_of_study  \
# 0       S001    Asha  Female   21        BSc Statistics              2
# 1       S002  Baraka    Male   22  BSc Computer Science              2
# 2       S003   Neema  Female   20      BSc Data Science              1
# 3       S004    Juma    Male   23        BSc Statistics              3
# 4       S005  Rehema  Female   21  BSc Computer Science              2
#
#    python_score  statistics_score  database_score  average_score
# 0            78                82              74      78.000000
# 1            65                70              68      67.666667
# 2            88                84              80      84.000000
# 3            55                60              58      57.666667
# 4            92                89              94      91.666667

# %% [markdown]
# Now create another column called `performance` using the following rule:
#
# | Average Score | Performance |
# |---|---|
# | 80 and above | Excellent |
# | 70 to 79 | Good |
# | 60 to 69 | Average |
# | Below 60 | Needs Improvement |

# %%
def classify_performance(score):
    # your code here

    return "the value you computed"

# %% [markdown]
# ## Task 6: Filtering Data
#
# Write Python commands to answer the following questions:
#
# 1. Show students with `average_score >= 80`.
# 2. Show students who scored below 60 in Python.
# 3. Show female students only.
# 4. Show students from `BSc Statistics`.
# 5. Show students in year 2 only.

# %%
# 1. Students with average_score >= 80
# Your code

# %%
# 2. Students who scored below 60 in Python
# Your code

# %%
# 3. Female students only
# Your code

# %%
# 4. Students from BSc Statistics
# your code

# %%
# 5. Students in year 2 only
# your code

# %% [markdown]
# ## Task 7: Grouping and Aggregation
#
# Use `groupby()` to answer the following questions:
#
# 1. What is the average score by gender?
# 2. What is the average Python score by program?
# 3. How many students are in each program?
# 4. What is the average score by year of study?

# %%
# 1. Average score by gender
# your code

# %%
# 2. Average Python score by program
# your code

# %%
# 3. Number of students in each program
# Your code

# %%
# 4. Average score by year of study
# Your code

# %% [markdown]
# ## Task 8: Sorting Data
#
# Sort the students in the following ways:
#
# 1. From highest to lowest average score.
# 2. From youngest to oldest.
# 3. From lowest to highest Python score.

# %%
# 1. Sort from highest to lowest average score
# Your code

# %%
# 2. Sort from youngest to oldest
# Your code

# %%
# 3. Sort from lowest to highest Python score
# Your code

# %% [markdown]
# ## Task 9: Basic Data Visualization
#
# Create four visualizations using Matplotlib.
#
# Make sure every chart has:
#
# - A clear title.
# - Proper x-axis label.
# - Proper y-axis label.
# - Readable values.

# %%
# 1. Bar chart of average score by student name
plt.figure(figsize=(10, 5))
#plt.bar(uncomment and put your code)
plt.xticks(rotation=45)
plt.title("Average Score by Student")
plt.xlabel("Student Name")
plt.ylabel("Average Score")
plt.show()

# %%
# 2. Bar chart showing number of students by program
program_counts = df["program"].value_counts()

plt.figure(figsize=(8, 5))
#plt.bar(Uncoment and write Your code)
plt.xticks(rotation=20)
plt.title("Number of Students by Program")
plt.xlabel("Program")
plt.ylabel("Number of Students")
plt.show()

# %%
# 3. Histogram of Python scores
plt.figure(figsize=(8, 5))
plt.hist(df["python_score"], bins=6, edgecolor="black")
plt.title("Distribution of Python Scores")
plt.xlabel("Python Score")
plt.ylabel("Frequency")
plt.show()

# %%
# 4. Scatter plot of Python score against Statistics score
plt.figure(figsize=(8, 5))
#plt.scatter(uncomment and your code goes here)
plt.title("Python Score vs Statistics Score")
plt.xlabel("Python Score")
plt.ylabel("Statistics Score")
plt.show()

# %% [markdown]
# ## Task 10: Short Summary on Theoretical linkage
#
# > Add blockquote
#
#
#
# Write your answers below in complete sentences. Your reflection should be between **5 and 8 sentences**.
#
# Discuss the following:
#
# 1. What is a dataset?
# 2. Why do we inspect data before analysis?
# 3. What does `groupby()` help us do?
# 4. How can Python help in big data analytics?
# 5. What challenges did you face in this exercise?

# %% [markdown]
# ### Student Reflection
#
# Write your reflection here:

# %% [markdown]
# ## Bonus Challenge
#
# Add one more column called `attendance_rate`. The values should be between 50 and 100.
#
# Then investigate whether students with higher attendance tend to have higher average scores using a scatter plot.

# %%
# Example attendance values. You may modify them.
df["attendance_rate"] = # Your code

df[["name", "attendance_rate", "average_score"]]
# Out:
#       name  attendance_rate  average_score
# 0     Asha               88      78.000000
# 1   Baraka               75      67.666667
# 2    Neema               95      84.000000
# 3     Juma               62      57.666667
# 4   Rehema               98      91.666667
# 5    Moses               80      72.666667
# 6   Fatuma               85      79.000000
# 7    Peter               55      52.000000
# 8    Grace               92      87.000000
# 9   Hassan               70      69.333333
# 10  Zawadi               78      74.666667
# 11  Kelvin               65      61.333333
# 12  Upendo               90      83.666667
# 13  Daniel               82      72.666667
# 14  Mariam               96      90.000000

# %%
plt.figure(figsize=(8, 5))

#plt.scatter(uncomment and your code goes here)

plt.title("Attendance Rate vs Average Score")
plt.xlabel("Attendance Rate")
plt.ylabel("Average Score")
plt.show()

# %% [markdown]
# ## Submission Checklist
#
# Before submitting, confirm that you have completed the following:
#
# - [ ] Created or used a dataset with at least 15 students.
# - [ ] Converted the dataset into a Pandas DataFrame.
# - [ ] Completed basic data inspection.
# - [ ] Calculated descriptive statistics.
# - [ ] Created `average_score` and `performance` columns.
# - [ ] Filtered, grouped, and sorted the data.
# - [ ] Created at least four charts.
# - [ ] Completed the written reflection.
# - [ ] Saved the notebook using the required file name.
